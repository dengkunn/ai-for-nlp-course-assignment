# %% [markdown]
# ## Assignment-07 First Step of using machine learning and models.

# %% [markdown]
# ### 任务描述

# %% [markdown]
# 报社等相关的机构，往往会遇到一个问题，就是别人家的机构使用自己的文章但是并没有标明来源。 在本次任务中，我们将解决新华社的文章被抄袭引用的问题。

# %% [markdown]
# 给定的数据集合中，存在一些新闻预料，该预料是来自新华社，但是其来源并不是新华社，请设计技巧学习模型解决该问题。

# %% [markdown]
# ### Step1: 数据分析

# %% [markdown]
# 请在课程的GitHub中下载数据集，然后使用pandas进行读取。

# %%
import pandas as pd
import jieba
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
fname = '/home/dk/kkb/ai-for-nlp-course-assignment/sqlResult_1558435.csv'
df = pd.read_csv(fname, encoding='gb18030')

# %% [markdown]
# ### Step2: 数据预处理

# %% [markdown]
# 将pandas中的数据，依据是否是新华社的文章，请改变成新的数据dataframe: <content, y>, 其中，content是文章内容，y是0或者1. 你可能要使用到pandas的dataframe操作。https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html

# %%
#source 和　content 为 NaN 的需要删除
#df[df.isna()['content']]
#df[df.isna()['source']]

df = df.dropna(subset=['source', 'content'])
#新华社新闻所占的比例
print (len(df[df['source'] == '新华社']) / len(df))
# Out:
# 0.903609336948031

# %%
#source列根据是“新华社”转化为label
df['source'] = df['source'].apply(lambda x : 1 if x == '新华社' else 0)

# %%
#数据清洗
#先尝试一下分词,去停用词的方案看下效果
def load_stopwords(fpath):
    return set([w.strip() for w in open(fpath, encoding='utf-8').readlines()])
stopwords = load_stopwords('./stopwords.txt')

# %%
pattern = r"[a-zA-Z\d\u3000\\n\r\n]" #数字字母等全部去除　\u3000中文空格符
pattern = re.compile(pattern)
corpus = []
p_ids = []
for i, row in enumerate(zip(df['id'], df['content'])):
    #if pd.isna(p): continue   #判断是否是空值
    p_id, p = row
    p = pattern.sub('', p)
    p = ' '. join([w for w in jieba.cut(p) if w not in stopwords])
    #p = re.sub('(\d )+', '#', p)
    corpus.append(p)
    p_ids.append(p_id)
    if i % 10000 == 0:
        print ('processing {} paragraphs.'.format(i))
# Out:
# processing 0 paragraphs.
# processing 10000 paragraphs.
# processing 20000 paragraphs.
# processing 30000 paragraphs.
# processing 40000 paragraphs.
# processing 50000 paragraphs.
# processing 60000 paragraphs.
# processing 70000 paragraphs.
# processing 80000 paragraphs.

# %% [markdown]
# ### Step3: 使用tfidf进行文本向量化

# %% [markdown]
# 参考 https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html 对

# %% [markdown]
# 对文本进行向量化

# %%
corpus = corpus
vectorizer = TfidfVectorizer(max_features=50000)
X = vectorizer.fit_transform(corpus)

# %%
y = df['source'].values

# %% [markdown]
# ### Step4: 参考scikit-learning的方法，构建你的第一个机器学习模型

# %% [markdown]
# + 按照课程讲解的内容，把数据集分割为 traning_data, validation_data, test_data. https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %% [markdown]
# + 参照scikit learning的示例，从构建你的第一个KNN机器学习模型。

# %%
X_train, X_test, y_train, y_test, p_ids_train, p_ids_test = train_test_split(X, y, p_ids, test_size=0.4, random_state=42)

# %%
X_val, X_test, y_val, y_test, p_ids_val, p_ids_test = train_test_split(X_test, y_test, p_ids_test, test_size=0.5, random_state=42)

# %%
print ("train data shape {}".format(X_train.shape))
print ("validation data shape {}".format(X_val.shape))
print ("test data shape {}".format(X_test.shape))
# Out:
# train data shape (52231, 50000)
# validation data shape (17410, 50000)
# test data shape (17411, 50000)

# %%
neigh = KNeighborsClassifier(n_neighbors=1)
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
neigh.score(X_val, y_val)
# Out:
# 0.9350947731188972

# %% [markdown]
# ### Step5: 在traning_data, validation_data, test_data 上观察其相关metric: recall, precision, f1等， 并解释其含义.

# %%
train_predict = neigh.predict(X_train)
val_predict = neigh.predict(X_val)
test_predict = neigh.predict(X_test)

# %%
target_names=["非新华社","新华社"]
print ("train data")
print(classification_report(y_train, train_predict, target_names=target_names))
print("***********************************************************************")
print ("val data")
print(classification_report(y_val, val_predict, target_names=target_names))
print("***********************************************************************")
print ("test data")
print(classification_report(y_test, test_predict, target_names=target_names))
# Out:
# train data
#               precision    recall  f1-score   support
#
#         非新华社       1.00      1.00      1.00      5075
#          新华社       1.00      1.00      1.00     47156
#
#     accuracy                           1.00     52231
#    macro avg       1.00      1.00      1.00     52231
# weighted avg       1.00      1.00      1.00     52231
#
# ***********************************************************************
# val data
#               precision    recall  f1-score   support
#
#         非新华社       0.85      0.37      0.52      1630
#          新华社       0.94      0.99      0.97     15780
#
#     accuracy                           0.94     17410
#    macro avg       0.89      0.68      0.74     17410
# weighted avg       0.93      0.94      0.92     17410
#
# ***********************************************************************
# test data
#               precision    recall  f1-score   support
#
#         非新华社       0.90      0.37      0.52      1686
#          新华社       0.94      1.00      0.97     15725
#
#     accuracy                           0.93     17411
#    macro avg       0.92      0.68      0.74     17411
# weighted avg       0.93      0.93      0.92     17411

# %% [markdown]
# ### Step6: 使用 test_data 对其进行新数据的判断, 你有没

# %%
# it's your time

# %% [markdown]
# ### Step7: 调整不同的参数，观察变化

# %% [markdown]
# 对“非新华社”也即label为０的召回率比较低，那么可以增加“非新华社”的权重,比如重复“非新华社”的样本；

# %%
# it's your time

# %% [markdown]
# ### Step8: 不断改变参数，直到性能达到“某个”点。问：“某个”怎么定义？

# %% [markdown]
# 对这个问题，是validation上的“新华社”的召回率要越高越好，当然同时其precision也要比较高，这样就不会把“抄袭”的文章给漏掉！

# %% [markdown]
# ### Step9: 找出所以预测为 1， 但是实际为 0 的文章。 作为抄袭的候选者。

# %% [markdown]
# 需要把实际数据的id给带上，如下判断抄袭的时候，才能知道具体的数据是什么，然后做分析：

# %%
print (y_test.shape)
print (test_predict.shape)
print (len(p_ids_test))
# Out:
# (17411,)
# (17411,)
# 17411

# %%
p_ids_final=[] #最终预测为１，实际为０的文章id list
for i, v in enumerate(zip(y_test, test_predict)):
    if v[0] == 0 and v[1] ==1:
        p_ids_final.append(p_ids_test[i])

# %%
len(p_ids_final)
# Out:
# 1068

# %%
df_result = df[df['id'].isin(p_ids_final)]

# %%
df_result
# Out:
#           id      author  source  \
# 6      89611         NaN       0
# 32     89585         NaN       0
# 52     89565         NaN       0
# 53     89564         NaN       0
# 54     89563  李天奕_NN7528       0
# 75     89542         NaN       0
# 80     89537         NaN       0
# 83     89534         NaN       0
# 87     89530         NaN       0
# 88     89529         NaN       0
# 102    89515         NaN       0
# 104    89513         NaN       0
# 117    89500         NaN       0
# 122    89495         NaN       0
# 126    89491  荀建国_NN7379       0
# 151    89466         陈晨1       0
# 158    89459         张田宇       0
# 160    89457         NaN       0
# 163    89454         NaN       0
# 177    89440         NaN       0
# 181    89436         张田宇       0
# 188    89429         NaN       0
# 192    89425         NaN       0
# 196    89421         张田宇       0
# 198    89419         张田宇       0
# 200    89417         NaN       0
# 214    89403  赵亚萍_NN9005       0
# 221    89396         NaN       0
# 233    89384  张海桐_NN9053       0
# 241    89376         NaN       0
# ...      ...         ...     ...
# 10680  78933         NaN       0
# 10694  78919         NaN       0
# 10698  78915         NaN       0
# 10701  78912         NaN       0
# 10703  78910          杨阳       0
# 10711  78902         NaN       0
# 10721  78892         NaN       0
# 10727  78886         NaN       0
# 10728  78885         NaN       0
# 10735  78878         NaN       0
# 10738  78875         NaN       0
# 10745  78868         NaN       0
# 10748  78865         NaN       0
# 10755  78858         NaN       0
# 10763  78850         NaN       0
# 10770  78843         NaN       0
# 10775  78838         NaN       0
# 10794  78818         NaN       0
# 10801  78811         NaN       0
# 10814  78798         NaN       0
# 10816  78796         NaN       0
# 10821  78791         NaN       0
# 10828  78784         NaN       0
# 10840  78772         NaN       0
# 10942  78670         NaN       0
# 10947  78665         NaN       0
# 10953  78659         NaN       0
# 10959  78653         NaN       0
# 10962  78650         NaN       0
# 10967  78645         NaN       0
#
#                                                  content  \
# 6      虽然至今夏普智能手机在市场上无法排得上号，已经完全没落，并于 2013 年退出中国市场，但是...
# 32     其他规格方面，搭载飞思卡尔IMX6SL处理器，内存512MB，存储8GB，采用定制版系统，低...
# 52     以下是文章主要内容：\r\n不妨想象一下未来的这一场景：你走进商店，凭名字通过带有脸部识别功...
# 53     央广网贵阳6月19日消息（记者王珩 贵州台记者黄瑾）为规范省级救灾储备物资管理，提高救灾物资...
# 54     （原标题：高速上50秒别车6次 面包车司机现身：我一时冲动犯了错）\r\n高速上50秒别车6...
# 75     虽然飞行时间只有八分钟左右，但从大约4分钟开始，火箭将部署10个胶囊。每个胶囊的大小都是可乐...
# 80     新疆日报讯（记者覃超祥报道）6月14日，玉山·买买提像往常一样来到新疆农业大学家属院7号楼，...
# 83     哈登和保罗联手，火箭会变成什么样子？这或许是一个非常疯狂的想法，毕竟快船正在用2亿顶薪去诱惑...
# 87     虽说没啥内容，可这则TVC将会在ICC期间播放，要是你知道印度人民对板球的喜好，自然会知道有...
# 6      {"type":"科技","site":"cnbeta","commentNum":"21"...
# 32     {"type":"科技","site":"cnbeta","commentNum":"64"...
# 52     {"type":"科技","site":"cnbeta","commentNum":"6",...
# 53     {"type":"国内新闻","site":"环球","commentNum":"0","j...
# 54     {"type":"新闻","site":"网易热门","commentNum":"1826"...
# 75     {"type":"科技","site":"cnbeta","commentNum":"4",...
# 80     {"type":"国内新闻","site":"环球","commentNum":"0","j...
# 83     {"type":"体育","site":"凤凰","commentNum":"30","jo...
# 87     {"type":"科技","site":"cnbeta","commentNum":"15"...
# 88     {"type":"中国财经","site":"参考消息","commentNum":"0",...
# 102    {"type":"国内新闻","site":"环球","commentNum":"0","j...
# 104    {"type":"金融市场","site":"参考消息","commentNum":"0",...
# 117    {"type":"中国财经","site":"参考消息","commentNum":"0",...
# 122    {"type":"国内新闻","site":"环球","commentNum":"0","j...
# 126    {"type":"新闻","site":"网易热门","commentNum":"1273"...
# 151    {"type":"时尚","site":"环球","commentNum":"0","joi...
# 158    {"type":"娱乐","site":"环球","commentNum":"0","joi...
# 160    {"type":"科技","site":"cnbeta","commentNum":"20"...
# 163    {"type":"科技","site":"cnbeta","commentNum":"2",...
# 177    {"type":"科技","site":"cnbeta","commentNum":"36"...
# 181    {"type":"娱乐","site":"环球","commentNum":"0","joi...
# 188    {"type":"科技","site":"cnbeta","commentNum":"8",...
# 192    {"type":"体育","site":"凤凰","commentNum":"0","joi...
# 196    {"type":"娱乐","site":"环球","commentNum":"0","joi...
# 198    {"type":"娱乐","site":"环球","commentNum":"0","joi...
# 200    {"type":"体育","site":"新浪","commentNum":" 35","j...
# 214    {"type":"新闻","site":"网易热门","commentNum":"639",...
# 221    {"type":"社会","site":"环球","commentNum":"0","joi...
# 233    {"type":"新闻","site":"网易热门","commentNum":"889",...
# 241    {"type":"体育","site":"凤凰","commentNum":"0","joi...
# ...                                                  ...
# 10680  {"type":"社会滚动","site":"参考消息","commentNum":"0",...
# 10694  {"type":"欧美新闻","site":"参考消息","commentNum":"0",...
# 10698  {"type":"要闻","site":"湖北日报","commentNum":"0","j...
# 10701  {"type":"神马新闻卡","site":"参考消息","commentNum":"0"...
# 10703  {"type":"台海","site":"环球热门","commentNum":"58","...
# 10711  {"type":"要闻综合","site":"郑州日报","commentNum":"0",...
# 10721  {"type":"要闻","site":"湖北日报","commentNum":"0","j...
# 10727  {"type":"头版","site":"河南日报","commentNum":"0","j...
# 10728  {"type":"封面","site":"南方日报","commentNum":"0","j...
# 10735  {"type":"体育","site":"广州日报","commentNum":"0","j...
# 10738  {"type":"要闻综合","site":"郑州日报","commentNum":"0",...
# 10745  {"type":"体育","site":"广州日报","commentNum":"0","j...
# 10748  {"type":"体育","site":"广州日报","commentNum":"0","j...
# 10755  {"type":"封面","site":"南方日报","commentNum":"0","j...
# 10763  {"type":"头版","site":"海南日报","commentNum":"0","j...
# 10770  {"type":"封面","site":"郑州日报","commentNum":"0","j...
# 10775  {"type":"封面","site":"郑州日报","commentNum":"0","j...
# 10794  {"type":"头版","site":"贵阳日报","commentNum":"0","j...
# 10801  {"type":"头版","site":"青海日报","commentNum":"0","j...
# 10814  {"type":"要闻","site":"南京日报","commentNum":"0","j...
# 10816  {"type":"头版","site":"贵阳日报","commentNum":"0","j...
# 10821  {"type":"封面","site":"昆明日报","commentNum":"0","j...
# 10828  {"type":"头版","site":"呼和浩特日报","commentNum":"0",...
# 10840  {"type":"军事","site":"头条","commentNum":"168","j...
# 10942  {"type":"封面","site":"南方日报","commentNum":"0","j...
# 10947  {"type":"头版","site":"海南日报","commentNum":"0","j...
# 10953  {"type":"第1纸·今日天下","site":"广州日报","commentNum":...
# 10959  {"type":"头版","site":"长江日报","commentNum":"0","j...
# 10962  {"type":"要闻","site":"成都商报","commentNum":"0","j...
# 10967  {"type":"头版","site":"长江日报","commentNum":"0","j...
#
#                                             title  \
# 6                             配骁龙660 全面屏鼻祖夏普新机酝酿中
# 32                    999元 - QQ阅读发布首款电子书：支持QQ微信登录
# 52                          亚马逊收购全食超市或预示着排队结账时代结束
# 53     贵州省出台省级救灾储备物资管理办法规定 灾情发生24小时内省级救灾物资须转运至目的地
# 54                       司机报复后车高速上50秒别车6次 被扣2分罚款2
# 75                             美国宇航局安排多彩火箭发射庆祝父亲节
# 80                      【民族团结一家亲】玉山·买买提：用爱心善举回报社会
# 83                    火箭可砸1.5亿打劫保罗？哈登CP3能打破勇士骑士垄断
# 87                      [动图]一加手机5真容曝光 真的不像是iPhone
# 88                            快讯：粤港澳概念股走俏 珠海港涨近4%
# 102                                 拜城：技能培训促残疾人就业
# 104                          粤港澳概念板块午后走强 珠海港等个股领涨
# 117                     基金周评：超八成基金上涨 再现巨额净赎回致净值暴涨
# 122                              神奇苇子峡：隐居天山的“桃花源”
# 126                       伊朗俄罗斯向卡塔尔提出援助 卡塔尔:暂时不需要
# 151                            夏日必备美鞋大盘点 大胆秀出纤细脚踝
# 158                       第二届澳门国际影展暨颁奖典礼 前所未见的新戏象
# 160                       马斯克希望用地下隧道缓解拥堵 洛杉矶市长同意了
# 163              [动图]Google Doodle父亲节涂鸦：带刺的爸爸内心柔软
# 177                          裂帛创始人回应称不堪京东欺压无奈关闭店铺
# 181                          《白鹿原》收官在即 精良品质敲响国剧强音
# 188                      刘强东：无人机将成为电商对接农村消费者的最佳方式
# 192                          京津德比开胃菜！曝国安球迷场外大战送餐员
# 196                       《桔子街的断货男》主题剧照 好父亲修炼秘籍揭秘
# 198                      赵传百忙之中现身公益活动 生日当天巡演预售开启
# 200                         曝拜仁担忧桑切斯玩套路！他或已铁心转会曼城
# 214                       小学生疑为校领导打伞 校方:校长专心颁证未注意
# 221                                 夏季到，海南出门常遇桃金娘
# 233                       两名男生中考前最后一课殴打班主任 老师连退几步
